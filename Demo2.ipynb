# %% [markdown]
# # Bent IC and Text Detection

# %%
from matplotlib import pyplot as plt
from PIL import Image
from detector import Detector
import os
from DataAugmentator import get_boxes, read_boxes, overlay_good_pins
# %matplotlib inline

# %%
de = Detector()
#de.add_to_command_tree('-no-text', [])
de.add_to_command_tree('-show', [])
de.add_to_command_tree('-apple-ocr', [])
de.add_to_command_tree('-enhance', [])
de.add_to_command_tree('-text-debug-mode', [True])
de.add_to_command_tree('-break-points', [False])
de.add_to_command_tree('-overlay-good-pin', ['c1'])
de.add_to_command_tree('-overlay-bent-pin', ['c0'])
de.add_to_command_tree('-overlay-package', ['c5'])
#de.add_to_command_tree('-model-n', [65])

input_image_folder  = './Images'

image_files = [f for f in os.listdir(input_image_folder) if f.endswith(('.png', '.jpg'))]

for i, image_file in enumerate(image_files):
    image_path = os.path.join(input_image_folder, image_file)
    image = Image.open(image_path).convert('RGB')
    image_width, image_height = image.size

    de.execute(image_path)
# Out:
# 0: 608x800 2 bents, 27 okays, 1 package, 1 text, 222.3ms
# Speed: 5.8ms preprocess, 222.3ms inference, 6.7ms postprocess per image at shape (1, 3, 608, 800)
# ### detector.py: It took 3.7015199661254883 seconds to execute!
# 0: 608x800 9 okays, 1 package, 1 text, 179.2ms
# Speed: 3.9ms preprocess, 179.2ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 800)
# ### detector.py: It took 1.7408738136291504 seconds to execute!
# 0: 608x800 21 bents, 22 okays, 1 package, 165.7ms
# Speed: 2.2ms preprocess, 165.7ms inference, 0.5ms postprocess per image at shape (1, 3, 608, 800)
# ### detector.py: It took 1.2851331233978271 seconds to execute!
# 0: 608x800 48 okays, 1 package, 1 text, 178.5ms
# Speed: 2.6ms preprocess, 178.5ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 800)
# ### detector.py: It took 1.8529059886932373 seconds to execute!
# 0: 608x800 48 okays, 1 package, 1 text, 187.7ms
# Speed: 3.1ms preprocess, 187.7ms inference, 0.6ms postprocess per image at shape (1, 3, 608, 800)
# ### detector.py: It took 1.7657849788665771 seconds to execute!
# 0: 608x800 2 bents, 65 okays, 1 package, 2 texts, 179.0ms
# Speed: 3.2ms preprocess, 179.0ms inference, 1.2ms postprocess per image at shape (1, 3, 608, 800)
# ### detector.py: It took 1.929063081741333 seconds to execute!
# 0: 608x800 6 okays, 1 package, 159.9ms
# Speed: 2.1ms preprocess, 159.9ms inference, 0.5ms postprocess per image at shape (1, 3, 608, 800)
# ### detector.py: It took 1.9454779624938965 seconds to execute!
# 0: 608x800 3 okays, 1 package, 183.8ms
# Speed: 2.1ms preprocess, 183.8ms inference, 0.5ms postprocess per image at shape (1, 3, 608, 800)
# ### detector.py: It took 1.576559066772461 seconds to execute!
