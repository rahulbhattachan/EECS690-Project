# %%
from matplotlib import pyplot as plt
from BoundingBox import BoundingBox
from PIL import Image

# %%
bb = BoundingBox("783-Pin-Detection/runs/detect/train56/weights/best.pt")

image = Image.open('783-Pin-Detection/datasets/ic-dataset/images/val/09.png')
overlay = bb.overlay(image, cl=[0, 2], color=[
    [255, 0, 0],
    [0, 255, 255]
])
plt.figure(figsize=[10, 5])
plt.imshow(overlay)
plt.show()
# Out:
# 0: 608x800 2 bents, 65 okays, 1 package, 2 texts, 154.1ms
# Speed: 5.0ms preprocess, 154.1ms inference, 81.6ms postprocess per image at shape (1, 3, 608, 800)
