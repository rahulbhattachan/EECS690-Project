# %%
from matplotlib import pyplot as plt
from BoundingBox import BoundingBox
from PIL import Image

# %%
bb = BoundingBox("783-Pin-Detection/runs/detect/train56/weights/best.pt")

image = Image.open('783-Pin-Detection/datasets/ic-dataset/images/val/09.png')
overlay = bb.overlay(image, cl=[0, 2], color=[
    [255, 0, 0],
    [0, 255, 255]
])
plt.figure(figsize=[10, 5])
plt.imshow(overlay)
plt.show()
# Out:
# 0: 608x800 2 bents, 65 okays, 1 package, 2 texts, 159.2ms
# Speed: 6.0ms preprocess, 159.2ms inference, 71.5ms postprocess per image at shape (1, 3, 608, 800)
# [array([       1781,      97.713,        1852,      243.85,     0.64349,           0], dtype=float32), array([     710.25,      1698.9,      762.78,      1868.4,      0.3058,           0], dtype=float32)]
#
# 0: 608x800 1 bent, 65 okays, 1 package, 2 texts, 24.0ms
# Speed: 11.0ms preprocess, 24.0ms inference, 3.0ms postprocess per image at shape (1, 3, 608, 800)
# [array([     555.97,       210.8,      2006.8,      1687.5,     0.89018,           2], dtype=float32)]
