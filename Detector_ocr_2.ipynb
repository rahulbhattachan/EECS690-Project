# %% [markdown]
# # Bent IC and Text Detection

# %%
from matplotlib import pyplot as plt
from PIL import Image
from detector import Detector
import os
from DataAugmentator import get_boxes, read_boxes, overlay_good_pins
# %matplotlib inline

# %%
de = Detector()
#de.add_to_command_tree('-no-text', [])
de.add_to_command_tree('-show', [])
de.add_to_command_tree('-apple-ocr', [])
de.add_to_command_tree('-enhance', [])
de.add_to_command_tree('-text-debug-mode', [False])
de.add_to_command_tree('-break-points', [False])
de.add_to_command_tree('-overlay-good-pin', ['c1'])
de.add_to_command_tree('-overlay-bent-pin', ['c0'])
de.add_to_command_tree('-overlay-package', ['c5'])
#de.add_to_command_tree('-model-n', [65])

input_image_folder  = './Images'

image_files = [f for f in os.listdir(input_image_folder) if f.endswith(('.png', '.jpg'))]

for i, image_file in enumerate(image_files):
    image_path = os.path.join(input_image_folder, image_file)
    image = Image.open(image_path).convert('RGB')
    image_width, image_height = image.size

    de.execute(image_path)
# Out:
# 0: 608x800 2 bents, 27 okays, 1 package, 1 text, 170.0ms
# Speed: 2.7ms preprocess, 170.0ms inference, 0.6ms postprocess per image at shape (1, 3, 608, 800)
# ### detector.py: It took 1.4085719585418701 seconds to execute!
# 0: 608x800 9 okays, 1 package, 1 text, 190.3ms
# Speed: 2.4ms preprocess, 190.3ms inference, 0.5ms postprocess per image at shape (1, 3, 608, 800)
# ### detector.py: It took 1.38761305809021 seconds to execute!
# 0: 608x800 21 bents, 22 okays, 1 package, 170.9ms
# Speed: 2.0ms preprocess, 170.9ms inference, 0.6ms postprocess per image at shape (1, 3, 608, 800)
# ### detector.py: It took 0.9044060707092285 seconds to execute!
# 0: 608x800 48 okays, 1 package, 1 text, 159.3ms
# Speed: 2.7ms preprocess, 159.3ms inference, 0.8ms postprocess per image at shape (1, 3, 608, 800)
# ### detector.py: It took 1.2687530517578125 seconds to execute!
# 0: 608x800 48 okays, 1 package, 1 text, 155.5ms
# Speed: 2.8ms preprocess, 155.5ms inference, 0.7ms postprocess per image at shape (1, 3, 608, 800)
# ### detector.py: It took 1.261937141418457 seconds to execute!
# 0: 608x800 2 bents, 65 okays, 1 package, 2 texts, 180.1ms
# Speed: 3.0ms preprocess, 180.1ms inference, 0.8ms postprocess per image at shape (1, 3, 608, 800)
# ### detector.py: It took 1.462348222732544 seconds to execute!
# 0: 608x800 6 okays, 1 package, 166.6ms
# Speed: 1.9ms preprocess, 166.6ms inference, 0.5ms postprocess per image at shape (1, 3, 608, 800)
# ### detector.py: It took 1.3071949481964111 seconds to execute!
# 0: 608x800 3 okays, 1 package, 167.3ms
# Speed: 2.9ms preprocess, 167.3ms inference, 0.6ms postprocess per image at shape (1, 3, 608, 800)
# ### detector.py: It took 0.9351620674133301 seconds to execute!
